# %% [markdown]
# # Practice problems:
# - https://www.w3resource.com/python-exercises/string/
# - https://pynative.com/python-string-exercise/

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_string = "Sonic"

len(my_string)
# Out:
# 5

# %% [markdown]
# # * ![image.png](attachment:image.png)

# %%
my_string = "Sonic"

#create function
def char_function(my_string):
    
    #initialize dictionary
    dictionary_my = {}
    #iteration
    for n in my_string:
        keys = dictionary_my.keys()
        if n in keys:
            dictionary_my += 1
        else:
            dictionary_my[n] = 1
    return dictionary_my
print("Counts of each letter in string: ", char_function(my_string))
# Out:
# Counts of each letter in string:  {'S': 1, 'o': 1, 'n': 1, 'i': 1, 'c': 1}

# %% [markdown]
# # ***
# Exercise 1A: Create a string made of the first, middle and last character
# Write a program to create a new string made of an input string’s first, middle, and last character.

# %%
my_string = "Sonic"

print(my_string[0],my_string[int((len(my_string)/2))],my_string[-1]
         )
# Out:
# S n c

# %% [markdown]
# # ***
# Exercise 1B: Create a string made of the middle three characters
# Write a program to create a new string made of the middle three characters of an input string.

# %%
# my_string = "JhonDipPeta"

# #get three middle letters
# # new_string = my_string[4:7]


# print(new_string)

def get_middle_three_chars(str1):
    print("Original String is", str1)

    # first get middle index number
    mi = int(len(str1) / 2)

    # use string slicing to get result characters
    res = str1[mi - 1:mi + 2]
    print("Middle three chars are:", res)

get_middle_three_chars("JhonDipPeta")
# Out:
# Original String is JhonDipPeta
# Middle three chars are: Dip

# %% [markdown]
# #***
#
# Question 3 from Pynative:

# %%
#define function 
def insert_middle(string1,string2):
    #get middle index value
    middle = int(len(string1)/2)
    
    #get everything from first half of string 1
    middle_append = string1[:middle:]
    
    #insert string 2 into middle of string 1
    middle_append = middle_append + string2
    
    #complete by adding last part of string 1
    middle_append = middle_append + string1[middle:]
    #print out result
    print("Appended string is: ",middle_append)
    
insert_middle("Hotdog","Chili")
# Out:
# Appended string is:  HotChilidog

# %%
# string1 = "toy"
# middle = int(len(string1)/2)
# first_half1 = string1[:middle:]

# first_half1
# Out:
# 't'
